# %%
import torch

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Thu Oct 26 02:54:26 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    10W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install pyDrive

# %% [markdown]
# # New Section

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
data = pd.read_csv('./gdrive/MyDrive/spam.csv', usecols = [0 , 1] , encoding = "latin")

# %% [markdown]
# ### usecols = [0 , 1 , ... , n]  使用0,1,...,n列的資料
# ## 順序無關,最後輸出的排序

# %%
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data = pd.read_csv('./gdrive/MyDrive/spam.csv', usecols = [1 , 0] , encoding = "latin")

# %%
data[0:10]
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...
# 6   ham  Even my brother is not like to speak with me. ...
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...
# 8  spam  WINNER!! As a valued network customer you have...
# 9  spam  Had your mobile 11 months or more? U R entitle...

# %%
#Import libraries for inporting files from Google deive to Colab
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
#Authhorize Google SDK to Acess Google Drive from Colab
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## 直接載入本地端,加快資料讀取

# %%
download = drive.CreateFile({'id' : '1EEB4kXKyAHCWDZsaJNHgH6cjflQHrbR5'})
download.GetContentFile('spam.csv')

# %%
! ls
# Out:
# gdrive	sample_data  spam.csv

# %% [markdown]
# ## 確認本地具有spam.csv檔案

# %%
import pandas as pd

# %%
data = pd.read_csv('./spam.csv' , usecols = [0 , 1] , encoding = "latin")
data[0:9]
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...
# 6   ham  Even my brother is not like to speak with me. ...
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...
# 8  spam  WINNER!! As a valued network customer you have...

# %% [markdown]
# ## 為何要將放在雲端的檔案,再次載入到本地
# ## 是可以將訓練好的權重直接儲存在Google雲端之中更新

# %%
import os

save_path = './gdrive/MyDrive'
data.to_csv(os.path.join(save_path , 'spam_colab_to_drive.csv') , index = False)
